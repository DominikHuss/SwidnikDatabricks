r><tr><td>ul. Niepodległości 12</td><td>146</td><td>954</td><td>1159</td><td>1298</td><td>1008</td><td>1020</td><td>822</td><td>295</td><td>194</td><td>238</td><td>665</td><td>812</td><td>920</td><td>774</td><td>851</td><td>495</td><td>273</td><td>null</td><td>85.0</td><td>775.0</td><td>803.0</td><td>818.0</td><td>757.0</td><td>729.0</td><td>594</td><td>427</td><td>209</td><td>186</td><td>590</td><td>701</td><td>1000</td><td>812</td><td>881</td><td>560</td><td>455</td><td>220</td><td>51.220289784684205</td><td>22.699083465767345</td></tr></tbody></table></div>

# %%
dates = ["2016-03-01",
         "2016-04-01",
         "2016-05-01",
         "2016-06-01",
         "2016-07-01",
         "2016-08-01",
         "2016-09-01",
         "2016-10-01",
         "2016-11-01",
         "2017-03-01",
         "2017-04-01",
         "2017-05-01",
         "2017-06-01",
         "2017-07-01",
         "2017-08-01",
         "2017-09-01",
         "2017-10-01",
         "2017-11-01",
         "2018-03-01",
         "2018-04-01",
         "2018-05-01",
         "2018-06-01",
         "2018-07-01",
         "2018-08-01",
         "2018-09-01",
         "2018-10-01",
         "2018-11-01",
         "2019-03-01",
         "2019-04-01",
         "2019-05-01",
         "2019-06-01",
         "2019-07-01",
         "2019-08-01",
         "2019-09-01",
         "2019-10-01",
         "2019-11-01"]
columns = list(set(df.columns)-set(["_c0", "x", "y"]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">36
# </div>

# %%
import pyspark.sql.functions as F
import pyspark.sql.types as T

d = df.select(F.col("_c0").alias("StreetName"),
              F.array(*columns).alias("arr"),
              F.col("x"),
              F.col("y"),
              F.array([F.lit(i) for i in dates]).alias("months"))
d = d.select(F.col("StreetName"),
             F.col("x"),
             F.col("y"),
             F.arrays_zip("arr", "months").alias("zipped"))
d = d.select(F.col("StreetName"),
             F.col("x"),
             F.col("y"),
             F.explode("zipped"))
d = d.select(F.col("StreetName"),
             F.col("x").cast(T.DoubleType()),
             F.col("y").cast(T.DoubleType()),
             F.col("col.arr").cast(T.IntegerType()).alias("value"),
             F.to_date(F.col("col.months")).alias("date"))
display(d)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>StreetName</th><th>x</th><th>y</th><th>value</th><th>date</th></tr></thead><tbody><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>359</td><td>2016-03-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>168</td><td>2016-04-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>223</td><td>2016-05-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>111</td><td>2016-06-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>408</td><td>2016-07-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>197</td><td>2016-08-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>124</td><td>2016-09-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>281</td><td>2016-10-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>212</td><td>2016-11-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>303</td><td>2017-03-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>278</td><td>2017-04-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>61</td><td>2017-05-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>339</td><td>2017-06-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>794</td><td>2017-07-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>117</td><td>2017-08-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>317</td><td>2017-09-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>215</td><td>2017-10-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>588</td><td>2017-11-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>168</td><td>2018-03-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>171</td><td>2018-04-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>241</td><td>2018-05-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>621</td><td>2018-06-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>86</td><td>2018-07-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>195</td><td>2018-08-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>7</td><td>2018-09-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>368</td><td>2018-10-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>358</td><td>2018-11-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>567</td><td>2019-03-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>null</td><td>2019-04-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>294</td><td>2019-05-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>17</td><td>2019-06-01</td></tr><tr><td>ul. Racławicka / ul. Wyszyńskiego</td><td>51.216073</td><td>22.698398</td><td>771</td><td>2019-07-01</td></tr><tr><td>ul. Racławicka / ul ...
